# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## But dans cette analyse
# #### Nom : "gc_data.csv"
# #### Source : ([https://sourceforge.net/projects/triangleinequal/files/Grad%20Cafe%20Data/gc_data.csv/download](https://sourceforge.net/projects/triangleinequal/files/Grad%20Cafe%20Data/gc_data.csv/download))
# #### Les colonnes que le dataset contiennent : 18
# #### visualisation des 5 premieres lignes du dataset
# #### Correlation
# #### Les variables qui pourront être dans X et Y ; est ce qu'il correspond a notre sujet

# %%
data = pd.read_csv("data/gc_data.csv")

# %%
data.shape
# Out:
# (2229, 18)

# %%
data.head()
# Out:
#                          School                    Program    Result  \
# 0  University Of South Carolina  Statistics, Masters (F14)  Rejected
# 1                    Iowa State      Statistics, PhD (F14)  Accepted
# 2     Arizona State  University      Statistics, PhD (F14)  Accepted
# 3         University Of Chicago      Statistics, PhD (F14)  Accepted
# 4         University Of Chicago      Statistics, PhD (F14)  Accepted
#
#    Result_Date   GPA  Verbal_GRE  Quant_GRE  Writing_GRE  Subject_GRE Status  \
# 0  22 Feb 2014   NaN         NaN        NaN          NaN          NaN    NaN
# 1  22 Feb 2014  3.65       153.0      168.0          3.0          NaN      I
# 2  10 Feb 2014  3.89       166.0      163.0          4.0          NaN      A
# 3  21 Feb 2014   NaN         NaN        NaN          NaN          NaN    NaN
# 4  22 Feb 2014  3.84       162.0      169.0          3.5         98.0      I
#
#    Submit_Date  Result_Day Result_Month  Result_Year  Submit_Day Submit_Month  \
# ...
